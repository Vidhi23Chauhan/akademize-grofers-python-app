# %%
import pandas as pd

# %%
pd.read_csv("dummy-data.csv") # df stabds for data frame
# Out:
#    item_id  is_p_off  is_p_off.1  is_flat_p  d_value      start_date  \
# 0        1         0           1          1      410  20/04/21 15:20
# 1        2         0           1          0      361  20/04/21 15:20
# 2        3         1           1          1       19  20/04/21 15:20
# 3        4         1           1          1       57  20/04/21 15:20
# 4        5         1           0          0      190  20/04/21 15:20
# 5        6         1           0          1      189  20/04/21 15:20
# 6        7         0           0          1       94  20/04/21 15:20
# 7        8         0           0          0      299  20/04/21 15:20
# 8        9         0           1          1      427  20/04/21 15:20
# 9       10         0           1          1      370  20/04/21 15:20
#
#          end_date
# 0  26/04/21 23:59
# 1  26/04/21 23:59
# 2  26/04/21 23:59
# 3  26/04/21 23:59
# 4  26/04/21 23:59
# 5  26/04/21 23:59
# 6  26/04/21 23:59
# 7  26/04/21 23:59
# 8  26/04/21 23:59
# ...

# %%
df = pd.read_csv("dummy-data.csv") # df stabds for data frame

# %%
df
# Out:
#    item_id  is_p_off  is_p_off.1  is_flat_p  d_value      start_date  \
# 0        1         0           1          1      410  20/04/21 15:20
# 1        2         0           1          0      361  20/04/21 15:20
# 2        3         1           1          1       19  20/04/21 15:20
# 3        4         1           1          1       57  20/04/21 15:20
# 4        5         1           0          0      190  20/04/21 15:20
# 5        6         1           0          1      189  20/04/21 15:20
# 6        7         0           0          1       94  20/04/21 15:20
# 7        8         0           0          0      299  20/04/21 15:20
# 8        9         0           1          1      427  20/04/21 15:20
# 9       10         0           1          1      370  20/04/21 15:20
#
#          end_date
# 0  26/04/21 23:59
# 1  26/04/21 23:59
# 2  26/04/21 23:59
# 3  26/04/21 23:59
# 4  26/04/21 23:59
# 5  26/04/21 23:59
# 6  26/04/21 23:59
# 7  26/04/21 23:59
# 8  26/04/21 23:59
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head() # displays first five records
# Out:
#    item_id  is_p_off  is_p_off.1  is_flat_p  d_value      start_date  \
# 0        1         0           1          1      410  20/04/21 15:20
# 1        2         0           1          0      361  20/04/21 15:20
# 2        3         1           1          1       19  20/04/21 15:20
# 3        4         1           1          1       57  20/04/21 15:20
# 4        5         1           0          0      190  20/04/21 15:20
#
#          end_date
# 0  26/04/21 23:59
# 1  26/04/21 23:59
# 2  26/04/21 23:59
# 3  26/04/21 23:59
# 4  26/04/21 23:59

# %%
df.tail() # # displays last five records
# Out:
#    item_id  is_p_off  is_p_off.1  is_flat_p  d_value      start_date  \
# 5        6         1           0          1      189  20/04/21 15:20
# 6        7         0           0          1       94  20/04/21 15:20
# 7        8         0           0          0      299  20/04/21 15:20
# 8        9         0           1          1      427  20/04/21 15:20
# 9       10         0           1          1      370  20/04/21 15:20
#
#          end_date
# 5  26/04/21 23:59
# 6  26/04/21 23:59
# 7  26/04/21 23:59
# 8  26/04/21 23:59
# 9  26/04/21 23:59

# %%
new_df = df["start_date"]

# %%
new_df
# Out:
# 0    20/04/21 15:20
# 1    20/04/21 15:20
# 2    20/04/21 15:20
# 3    20/04/21 15:20
# 4    20/04/21 15:20
# 5    20/04/21 15:20
# 6    20/04/21 15:20
# 7    20/04/21 15:20
# 8    20/04/21 15:20
# 9    20/04/21 15:20
# Name: start_date, dtype: object

# %%
type(new_df)
# Out:
# pandas.core.series.Series

# %%
titanic = pd.read_csv("titanic_data.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.to_excel("titanic.xlsx", sheet_name="passengers", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-ef3e997cc15f> in <module>
# ----> 1 titanic.to_excel("titanic.xlsx", sheet_name="passengers", index=False)
#
# ~/Documents/akademize-grofers-python-app/.venv/lib/python3.9/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~/Documents/akademize-grofers-python-app/.venv/lib/python3.9/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
# ...

# %%
age_sex = titanic[["Age", "Sex"]]

# %%
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
type(titanic[["Age", "Sex"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic[["Age", "Sex"]].shape
# Out:
# (891, 2)

# %%
below_18 = titanic[titanic["Age"] < 18]

# %%
below_18
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
below_18.shape
# Out:
# (113, 12)

# %%
class_12 = titanic[titanic["Pclass"].isin([1, 2])]

# %%
class_12.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %%
class_12 = titanic[(titanic["Pclass"] == 1) | (titanic["Pclass"] == 2)]

# %%
class_12.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %%
class_12 = titanic[(titanic["Pclass"] == 1) & (titanic["Pclass"] == 2)]

# %%
class_12.head()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
age_no_na = titanic[titanic["Age"].notna()]

# %%
age_no_na.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
adult_names = titanic.loc[titanic["Age"] < 18, "Name"]

# %%
adult_names.head()
# Out:
# 7           Palsson, Master. Gosta Leonard
# 9      Nasser, Mrs. Nicholas (Adele Achem)
# 10         Sandstrom, Miss. Marguerite Rut
# 14    Vestrom, Miss. Hulda Amanda Adolfina
# 16                    Rice, Master. Eugene
# Name: Name, dtype: object

# %%
n_df1 = df[["item_id","d_value","start_date"]]
type(n_df1)
# Out:
# pandas.core.frame.DataFrame

# %%
n_df1.to_csv("start_date.csv", index=False)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.columns
# Out:
# Index(['item_id', 'is_p_off', 'is_p_off.1', 'is_flat_p', 'd_value',
#        'start_date', 'end_date'],
#       dtype='object')

# %%
df_3 = pd.DataFrame(
     {    'age': [12,19],
      'height': [94,170],
      'weight': [31,115]
     }
)

# %%
df_3
# Out:
#    age  height  weight
# 0   12      94      31
# 1   19     170     115
